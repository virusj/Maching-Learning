# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("CAR DETAILS FROM CAR DEKHO.csv")
data.head(11)
# Out:
#                          name  year  selling_price  km_driven    fuel  \
# 0               Maruti 800 AC  2007          60000      70000  Petrol
# 1    Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2        Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3      Datsun RediGO T Option  2017         250000      46000  Petrol
# 4       Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5        Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6   Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7    Tata Indigo Grand Petrol  2014         240000      60000  Petrol
# 8    Hyundai Creta 1.6 VTVT S  2015         850000      25000  Petrol
# 9    Maruti Celerio Green VXI  2017         365000      78000     CNG
# 10    Chevrolet Sail 1.2 Base  2015         260000      35000  Petrol
#
#    seller_type transmission         owner
# 0   Individual       Manual   First Owner
# ...

# %%
data.shape
# Out:
# (4340, 8)

# %%
data["year"]
# Out:
# 0       2007
# 1       2007
# 2       2012
# 3       2017
# 4       2014
#         ...
# 4335    2014
# 4336    2014
# 4337    2009
# 4338    2016
# 4339    2016
# Name: year, Length: 4340, dtype: int64

# %%
data.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
data.drop(columns =["name"],inplace = True)

# %%
data
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2007          60000      70000  Petrol  Individual       Manual
# 1     2007         135000      50000  Petrol  Individual       Manual
# 2     2012         600000     100000  Diesel  Individual       Manual
# 3     2017         250000      46000  Petrol  Individual       Manual
# 4     2014         450000     141000  Diesel  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 4335  2014         409999      80000  Diesel  Individual       Manual
# 4336  2014         409999      80000  Diesel  Individual       Manual
# 4337  2009         110000      83000  Petrol  Individual       Manual
# 4338  2016         865000      90000  Diesel  Individual       Manual
# 4339  2016         225000      40000  Petrol  Individual       Manual
#
#              owner
# 0      First Owner
# 1      First Owner
# 2      First Owner
# 3      First Owner
# 4     Second Owner
# ...

# %%
data["fuel"]=data["fuel"].map({"Petrol":0, "Diesel":1})
data.head(11)
# Out:
#     year  selling_price  km_driven  fuel seller_type transmission  \
# 0   2007          60000      70000   0.0  Individual       Manual
# 1   2007         135000      50000   0.0  Individual       Manual
# 2   2012         600000     100000   1.0  Individual       Manual
# 3   2017         250000      46000   0.0  Individual       Manual
# 4   2014         450000     141000   1.0  Individual       Manual
# 5   2007         140000     125000   0.0  Individual       Manual
# 6   2016         550000      25000   0.0  Individual       Manual
# 7   2014         240000      60000   0.0  Individual       Manual
# 8   2015         850000      25000   0.0  Individual       Manual
# 9   2017         365000      78000   NaN  Individual       Manual
# 10  2015         260000      35000   0.0  Individual       Manual
#
#            owner
# 0    First Owner
# 1    First Owner
# 2    First Owner
# 3    First Owner
# 4   Second Owner
# 5    First Owner
# 6    First Owner
# 7   Second Owner
# ...

# %%
data["transmission"]=data["transmission"].map({"Manual":0 , "Automatic":1})
data.head(21)
# Out:
#     year  selling_price  km_driven  fuel seller_type  transmission  \
# 0   2007          60000      70000   0.0  Individual             0
# 1   2007         135000      50000   0.0  Individual             0
# 2   2012         600000     100000   1.0  Individual             0
# 3   2017         250000      46000   0.0  Individual             0
# 4   2014         450000     141000   1.0  Individual             0
# 5   2007         140000     125000   0.0  Individual             0
# 6   2016         550000      25000   0.0  Individual             0
# 7   2014         240000      60000   0.0  Individual             0
# 8   2015         850000      25000   0.0  Individual             0
# 9   2017         365000      78000   NaN  Individual             0
# 10  2015         260000      35000   0.0  Individual             0
# 11  2014         250000     100000   0.0  Individual             0
# 12  2018        1650000      25000   0.0      Dealer             1
# ...

# %%
data["seller_type"]=data["seller_type"].map({"Individual":0 , "Dealer":1})
data.head(20)
# Out:
#     year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0   2007          60000      70000   0.0          0.0             0
# 1   2007         135000      50000   0.0          0.0             0
# 2   2012         600000     100000   1.0          0.0             0
# 3   2017         250000      46000   0.0          0.0             0
# 4   2014         450000     141000   1.0          0.0             0
# 5   2007         140000     125000   0.0          0.0             0
# 6   2016         550000      25000   0.0          0.0             0
# 7   2014         240000      60000   0.0          0.0             0
# 8   2015         850000      25000   0.0          0.0             0
# 9   2017         365000      78000   NaN          0.0             0
# 10  2015         260000      35000   0.0          0.0             0
# 11  2014         250000     100000   0.0          0.0             0
# 12  2018        1650000      25000   0.0          1.0             1
# ...

# %%
data["owner"] = data["owner"].map({"First Owner":0 , "Second Owner":1})
data.head(11)
# Out:
#     year  selling_price  km_driven  fuel  seller_type  transmission  owner
# 0   2007          60000      70000   0.0          0.0             0    0.0
# 1   2007         135000      50000   0.0          0.0             0    0.0
# 2   2012         600000     100000   1.0          0.0             0    0.0
# 3   2017         250000      46000   0.0          0.0             0    0.0
# 4   2014         450000     141000   1.0          0.0             0    1.0
# 5   2007         140000     125000   0.0          0.0             0    0.0
# 6   2016         550000      25000   0.0          0.0             0    0.0
# 7   2014         240000      60000   0.0          0.0             0    1.0
# 8   2015         850000      25000   0.0          0.0             0    0.0
# 9   2017         365000      78000   NaN          0.0             0    0.0
# 10  2015         260000      35000   0.0          0.0             0    0.0

# %%
sns.barplot(x=data["km_driven"],y=data["fuel"])
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='fuel'>

# %%
sns.distplot(data["selling_price"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %%
data.isnull().sum()
# Out:
# year               0
# selling_price      0
# km_driven          0
# fuel              64
# seller_type      102
# transmission       0
# owner            402
# dtype: int64

# %%
data["fuel"]=data["fuel"].map({"CGN":2})
data.isnull().sum()
# Out:
# year                0
# selling_price       0
# km_driven           0
# fuel             4340
# seller_type       102
# transmission        0
# owner             402
# dtype: int64

# %%
data.head(50)
# Out:
#     year  selling_price  km_driven  fuel  seller_type  transmission  owner
# 0   2007          60000      70000   NaN          0.0             0    0.0
# 1   2007         135000      50000   NaN          0.0             0    0.0
# 2   2012         600000     100000   NaN          0.0             0    0.0
# 3   2017         250000      46000   NaN          0.0             0    0.0
# 4   2014         450000     141000   NaN          0.0             0    1.0
# 5   2007         140000     125000   NaN          0.0             0    0.0
# 6   2016         550000      25000   NaN          0.0             0    0.0
# 7   2014         240000      60000   NaN          0.0             0    1.0
# 8   2015         850000      25000   NaN          0.0             0    0.0
# 9   2017         365000      78000   NaN          0.0             0    0.0
# 10  2015         260000      35000   NaN          0.0             0    0.0
# ...

# %%
data.isnull().sum()
# Out:
# year                0
# selling_price       0
# km_driven           0
# fuel             4340
# seller_type       102
# transmission        0
# owner             402
# dtype: int64
